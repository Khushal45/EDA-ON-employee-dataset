# %% [markdown]
# # EXPLORATARY DATA ANALYSIS OF EMPLOYEES

# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv("employees.csv")
df.head(50)
# Out:
#    First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0     Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1      Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2       Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3       Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4       Larry    Male   1/24/1998         4:47 PM  101004    1.389
# 5      Dennis    Male   4/18/1987         1:35 AM  115163   10.125
# 6        Ruby  Female   8/17/1987         4:20 PM   65476   10.012
# 7         NaN  Female   7/20/2015        10:43 AM   45906   11.598
# 8      Angela  Female  11/22/2005         6:29 AM   95570   18.523
# 9     Frances  Female    8/8/2002         6:51 AM  139852    7.524
# 10     Louise  Female   8/12/1980         9:01 AM   63241   15.132
# 11      Julie  Female  10/26/1997         3:19 PM  102508   12.637
# 12    Brandon    Male   12/1/1980         1:08 AM  112807   17.492
# ...

# %%
df.tail()
# Out:
#     First Name Gender  Start Date Last Login Time  Salary  Bonus %  \
# 995      Henry    NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip   Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell   Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry   Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert   Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 995             False          Distribution
# 996             False               Finance
# 997             False               Product
# 998             False  Business Development
# 999              True                 Sales

# %%
df.columns
# Out:
# Index(['First Name', 'Gender', 'Start Date', 'Last Login Time', 'Salary',
#        'Bonus %', 'Senior Management', 'Team'],
#       dtype='object')

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
#converting start date column to datetime data type
df['Start Date']=pd.to_datetime(df['Start Date'],format='mixed')

# %%
df.dtypes
# Out:
# First Name                   object
# Gender                       object
# Start Date           datetime64[ns]
# Last Login Time              object
# Salary                        int64
# Bonus %                     float64
# Senior Management            object
# Team                         object
# dtype: object

# %%
import pandas as pd

# Assuming df is your DataFrame
df['Last Login Time'] = pd.to_datetime(df['Last Login Time'], format='mixed')

# %%
columns={'First Name':'First_Name','Start Date':'Start_Date' 
         ,'Last Login Time':'Last_Login_Time','Bonus %':'Bonus_perc','Senior Management':'Senior_Management'}
df.rename(columns=columns,inplace=True)

# %%
df.columns
# Out:
# Index(['First_Name', 'Gender', 'Start_Date', 'Last_Login_Time', 'Salary',
#        'Bonus_perc', 'Senior_Management', 'Team'],
#       dtype='object')

# %%
df.nunique()
# Out:
# First_Name           200
# Gender                 2
# Start_Date           972
# Last_Login_Time      720
# Salary               995
# Bonus_perc           971
# Senior_Management      2
# Team                  10
# dtype: int64

# %% [raw]
# #handling the missing values

# %%
df.isnull().sum()
# Out:
# First_Name            67
# Gender               145
# Start_Date             0
# Last_Login_Time        0
# Salary                 0
# Bonus_perc             0
# Senior_Management     67
# Team                  43
# dtype: int64

# %%
df['Gender'].fillna('No Gender',inplace=True)

# %%
df.isnull().sum()
# Out:
# First_Name           67
# Gender                0
# Start_Date            0
# Last_Login_Time       0
# Salary                0
# Bonus_perc            0
# Senior_Management    67
# Team                 43
# dtype: int64

# %%
df['Senior_Management'].mode()
# Out:
# 0    True
# Name: Senior_Management, dtype: object

# %%
mode=df['Senior_Management'].mode()[0]
mode
# Out:
# True

# %%
df['Senior_Management']=df['Senior_Management'].replace(np.nan,mode)

# %%
df.isnull().sum()
# Out:
# First_Name           67
# Gender                0
# Start_Date            0
# Last_Login_Time       0
# Salary                0
# Bonus_perc            0
# Senior_Management     0
# Team                 43
# dtype: int64

# %%
df['Team'].value_counts()
# Out:
# Team
# Client Services         106
# Finance                 102
# Business Development    101
# Marketing                98
# Product                  95
# Sales                    94
# Engineering              92
# Human Resources          91
# Distribution             90
# Legal                    88
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# First_Name           67
# Gender                0
# Start_Date            0
# Last_Login_Time       0
# Salary                0
# Bonus_perc            0
# Senior_Management     0
# Team                 43
# dtype: int64

# %%
df=df.dropna(axis=0,how='any')

# %%
df.isnull().sum()
# Out:
# First_Name           0
# Gender               0
# Start_Date           0
# Last_Login_Time      0
# Salary               0
# Bonus_perc           0
# Senior_Management    0
# Team                 0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 899 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First_Name         899 non-null    object
#  1   Gender             899 non-null    object
#  2   Start_Date         899 non-null    datetime64[ns]
#  3   Last_Login_Time    899 non-null    datetime64[ns]
#  4   Salary             899 non-null    int64
#  5   Bonus_perc         899 non-null    float64
#  6   Senior_Management  899 non-null    bool
#  7   Team               899 non-null    object
# dtypes: bool(1), datetime64[ns](2), float64(1), int64(1), object(3)
# memory usage: 57.1+ KB

# %%
df=df.reset_index()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 899 entries, 0 to 898
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              899 non-null    int64
#  1   First_Name         899 non-null    object
#  2   Gender             899 non-null    object
#  3   Start_Date         899 non-null    datetime64[ns]
#  4   Last_Login_Time    899 non-null    datetime64[ns]
#  5   Salary             899 non-null    int64
#  6   Bonus_perc         899 non-null    float64
#  7   Senior_Management  899 non-null    bool
#  8   Team               899 non-null    object
# dtypes: bool(1), datetime64[ns](2), float64(1), int64(2), object(3)
# memory usage: 57.2+ KB

# %% [markdown]
# # data visualization

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
sns.histplot(x='Salary',data=df)
plt.show()
#these graph says it has the uniform distn
# Out:
# E:\Personal\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(x='Bonus_perc',hue='Gender',data=df,alpha=0.6)
plt.show()
# Out:
# E:\Personal\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.boxplot(x='Salary',y='Team',data=df)
plt.show()
#if the the median line is on the right side then right skewed 
#and left lef skewed

# %%
sns.boxplot(x='Salary',y='Gender',data=df)
plt.show()

# %%
sns.scatterplot(x='Salary',y='Bonus_perc',data=df,hue='Team')
plt.legend(bbox_to_anchor=(1,1),loc=2)
plt.show()

# %%
df['Salary'].corr(df['Bonus_perc'])
# Out:
# -0.01702025486966284

# %%
sns.pairplot(df,hue='Gender',height=2)
# Out:
# E:\Personal\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# E:\Personal\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# E:\Personal\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# E:\Personal\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# ...

# %% [markdown]
# # handling the outliers

# %%
df=sns.load_dataset('Iris')
print(df.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.boxplot(x=df['sepal_width'],data=df)
# Out:
# <Axes: xlabel='sepal_width'>

# %%
df.shape
# Out:
# (150, 5)

# %%
#iqr
Q1=np.percentile(df['sepal_width'],25,method='midpoint')
Q3=np.percentile(df['sepal_width'],75,method='midpoint')
IQR=Q3-Q1
print('old shape: ',df.shape)
Upper=Q3+1.5*IQR
print(Upper)
Lower=Q1-1.5*IQR
print(Lower)
# Out:
# old shape:  (150, 5)
# 4.05
# 2.05

# %%
Q1=np.percentile(df['sepal_width'],25,method='midpoint')
Q3=np.percentile(df['sepal_width'],75,method='midpoint')

# %%
Q1,Q3
# Out:
# (2.8, 3.3)

# %%
#upper bound
max_upper_value=np.where(df['sepal_width']>=Upper)
print(max_upper_value)
# Out:
# (array([15, 32, 33], dtype=int64),)

# %%
min_lower_value=np.where(df['sepal_width']<=Lower)
print(min_lower_value)
# Out:
# (array([60], dtype=int64),)

# %%
df.head(35)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %%
df.drop(max_upper_value[0],inplace=True)

# %%
df.drop(min_lower_value[0],inplace=True)

# %%
print("New Shape: ",df.shape)
# Out:
# New Shape:  (147, 5)

# %%
sns.boxplot(x='sepal_width',data=df)
# Out:
# <Axes: xlabel='sepal_width'>

# %%
import pandas as pd

sample_df=pd.read_csv("Global-Superstore.csv")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[52], line 3
#       1 import pandas as pd
# ----> 3 sample_df=pd.read_csv("Global-Superstore.csv")
#
# File E:\Personal\Lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd

# Try reading the file with a different encoding
sample_df = pd.read_csv("Global-Superstore.csv", encoding='latin1')

# %%
sample_df
# Out:
#        Row ID         Order ID  Order Date   Ship Date       Ship Mode  \
# 0       32298   CA-2012-124891   7/31/2012   7/31/2012        Same Day
# 1       26341    IN-2013-77878    2/5/2013    2/7/2013    Second Class
# 2       25330    IN-2013-71249  10/17/2013  10/18/2013     First Class
# 3       13524  ES-2013-1579342   1/28/2013   1/30/2013     First Class
# 4       47221     SG-2013-4320   11/5/2013   11/6/2013        Same Day
# ...       ...              ...         ...         ...             ...
# 51285   29002    IN-2014-62366   6/19/2014   6/19/2014        Same Day
# 51286   35398   US-2014-102288   6/20/2014   6/24/2014  Standard Class
# 51287   40470   US-2013-155768   12/2/2013   12/2/2013        Same Day
# 51288    9596   MX-2012-140767   2/18/2012   2/22/2012  Standard Class
# 51289    6147   MX-2012-134460   5/22/2012   5/26/2012    Second Class
#
#       Customer ID     Customer Name      Segment           City  \
# ...

# %%
sample_df.shape
# Out:
# (51290, 24)

# %%
sample_df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country',
#        'Postal Code', 'Market', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
# !pip install xlrd
# Out:
# ...
#   Obtaining dependency information for xlrd from https://files.pythonhosted.org/packages/a6/0c/c2a72d51fe56e08a08acc85d13013558a2d793028ae7385448a6ccdfae64/xlrd-2.0.1-py2.py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/96.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/96.5 kB ? eta -:--:--
#    ---- ----------------------------------- 10.2/96.5 kB ? eta -:--:--
#    ---------------- ----------------------- 41.0/96.5 kB 393.8 kB/s eta 0:00:01
#    ---------------------------------------- 96.5/96.5 kB 791.7 kB/s eta 0:00:00
# ...

# %%
sample_df=pd.read_excel(r"C:\Users\Mandar Patil\Downloads\global_superstore_2016.xlsx")
sample_df
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# ...       ...                       ...        ...        ...             ...
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...

# %%
sample_df.shape
# Out:
# (51290, 24)

# %%
sample_df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Postal Code', 'City',
#        'State', 'Country', 'Region', 'Market', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')
